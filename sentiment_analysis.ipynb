# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tabulate
# Out:
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (0.9.0)

# %%
import pandas as pd
import nltk
import re
from tabulate import tabulate
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from sklearn.preprocessing import LabelEncoder
from nltk.util import ngrams
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %% [markdown]
# ## **1. Creating the dataset**

# %%
with open('/content/drive/MyDrive/L4S1/CM 4340 | Natural Language Processing/Assignment 02/Movie_Reviews.txt', 'r') as file:
    lines = file.readlines()

# %% [markdown]
# * Removed lines with empty strings

# %%
filtered_lines = [line for line in lines if line != '\n']
filtered_lines
# Out:
# ['Positive Reviews\n',
#  '================\n',
#  '1. "Forrest Gump is an absolute masterpiece! Tom Hanks delivers an unforgettable performance, and the storytelling is heartwarming. This movie is a journey through life that will make you laugh, cry, and appreciate the simple beauties of existence."\n',
#  '2. "The Shawshank Redemption is a timeless classic. The powerful themes of hope, friendship, and redemption make it a must-watch. Morgan Freeman and Tim Robbins give exceptional performances in this brilliantly crafted film."\n',
#  '3. "The epic conclusion to The Lord of the Rings trilogy, The Return of the King, is a cinematic triumph. The breathtaking visuals, epic battles, and emotionally resonant story make it a monumental achievement in filmmaking."\n',
#  '4. "La La Land is a love letter to the magic of Hollywood and dreams. The chemistry between Ryan Gosling and Emma Stone is enchanting, and the music and dance sequences are a pure delight. A modern musical masterpiece."\n',
#  '5. "Wes Anderson\'s whimsical style shines in The Grand Budapest Hotel. With its quirky characters and colorful cinematography, it\'s a visual and narrative delight. This film is a charming and delightful experience."\n',
#  '6."Inception is mind-bending brilliance! Christopher Nolan\'s intricate plot, stunning visual effects, and Hans Zimmer\'s haunting score create a cinematic journey that keeps you on the edge of your seat. A true masterpiece of sci-fi cinema."\n',
#  '7. "The Social Network is a captivating exploration of the creation of Facebook and the personal and legal conflicts that ensued. David Fincher\'s direction and Aaron Sorkin\'s sharp screenplay make this film a modern classic."\n',
#  '8. "Will Smith\'s portrayal of Chris Gardner in The Pursuit of Happyness is both touching and inspirational. This film reminds us that with determination and unwavering spirit, anyone can overcome adversity to achieve their dreams."\n',
#  '9. "Eternal Sunshine of the Spotless Mind is a beautifully unconventional love story. Jim Carrey and Kate Winslet shine in their roles, and the narrative, told in a non-linear fashion, is a poignant exploration of love, memories, and human connection."\n',
#  '10. "The Princess Bride is a timeless fairy tale with a perfect blend of humor, romance, and adventure. Its witty dialogue and memorable characters make it a film that appeals to both kids and adults. Inconceivably delightful!"\n',
#  '11. "Fifty Shades of Grey" has managed to captivate both enthusiasts and critics alike. The film\'s ability to spark passionate discussions and elicit a wide range of opinions is a testament to its impact. While some may find it controversial, there\'s no denying that it has left a significant mark on the world of cinema.\n',
#  '12. "This film has been a conversation starter, and it\'s clear that it won\'t be everyone\'s cup of tea. But for those willing to approach it with an open mind, there\'s a visually lush experience with moments of genuine chemistry between the leads. It\'s a film that has managed to offer something different and intriguing in the world of romance and drama."\n',
#  'Negative Reviews\n',
#  '================\n',
#  '1. "The Last Airbender is a disaster of a film adaptation. It butchers the beloved animated series with wooden acting, convoluted storytelling, and cringe-worthy special effects. A letdown for fans and newcomers alike."\n',
#  '2. "Another Transformers movie, and it\'s just more of the same: mindless explosions, incoherent plotlines, and an overreliance on CGI. This franchise desperately needs an overhaul."\n',
#  '3. "The Emoji Movie is a blatant cash grab with a shallow, uninspired plot. It fails to deliver clever humor or meaningful messages, making it a forgettable and disappointing animated film."\n',
#  '4. "Fifty Shades of Grey is a cringe-inducing attempt at romance. Poorly written dialogue and unconvincing chemistry between the leads make it an awkward and unfulfilling cinematic experience."\n',
#  '5. "Jack and Jill is an unbearable comedy that relies on stale humor and a painfully unfunny portrayal of Adam Sandler in a dual role. It\'s a prime example of lazy filmmaking."\n',
#  '6. "Superman IV is a colossal disappointment. It\'s marred by a low budget, laughable special effects, and a poorly conceived story. Even Christopher Reeve\'s charm can\'t save this mess."\n',
#  '7. "The Cat in the Hat is a chaotic and misguided adaptation of Dr. Seuss\'s classic. It sacrifices the charm and simplicity of the source material for crude humor and a lackluster narrative."\n',
#  '8. "The Room is widely regarded as one of the worst films ever made. Its disjointed plot, stilted acting, and bizarre dialogue have turned it into a cult classic, but not for the right reasons."\n',
#  '9. "Battlefield Earth is a sci-fi disaster. It\'s a convoluted mess with hammy acting and laughable special effects. A film that should have remained buried in the annals of cinematic history."\n',
#  '10. "Gigli is a train wreck of a romantic comedy. The pairing of Ben Affleck and Jennifer Lopez is devoid of chemistry, and the dialogue is cringeworthy. It\'s an embarrassing misstep in both their careers."\n',
#  '11. "Fifty Shades of Grey" is a film that has divided enthusiasts and critics. While it has its share of devoted fans, it also faces substantial criticism. For some, the film\'s content and execution leave much to be desired, making it a polarizing cinematic experience. Viewer reactions may vary widely, so it\'s a movie that evokes strong opinions on both ends of the spectrum.\n',
#  '12. "This film\'s portrayal of relationships and themes may leave many viewers uncomfortable. It tests the limits of what some may find acceptable in mainstream cinema. So, while the idea of keeping an open mind is essential in film-watching, this particular movie might push that openness to its boundaries for some."\n',
#  '=====================================================================\n',
#  "It's clear that the movie has both its enthusiasts and critics. While it may not be to everyone's taste, it's worth watching with an open mind to form your own opinion. \n"]

# %% [markdown]
# * Finding the indexes of lines having "=" characters

# %%
indexes = [index for index, item in enumerate(filtered_lines) if "===" in item]
indexes
# Out:
# [1, 15, 28]

# %% [markdown]
# * Splitting lines into positive, negative and test review sets

# %%
positive_reviews = filtered_lines[2:14]
negative_reviews = filtered_lines[16:28]
test_reviews = filtered_lines[29:]

# %%
positive_reviews
# Out:
# ['1. "Forrest Gump is an absolute masterpiece! Tom Hanks delivers an unforgettable performance, and the storytelling is heartwarming. This movie is a journey through life that will make you laugh, cry, and appreciate the simple beauties of existence."\n',
#  '2. "The Shawshank Redemption is a timeless classic. The powerful themes of hope, friendship, and redemption make it a must-watch. Morgan Freeman and Tim Robbins give exceptional performances in this brilliantly crafted film."\n',
#  '3. "The epic conclusion to The Lord of the Rings trilogy, The Return of the King, is a cinematic triumph. The breathtaking visuals, epic battles, and emotionally resonant story make it a monumental achievement in filmmaking."\n',
#  '4. "La La Land is a love letter to the magic of Hollywood and dreams. The chemistry between Ryan Gosling and Emma Stone is enchanting, and the music and dance sequences are a pure delight. A modern musical masterpiece."\n',
#  '5. "Wes Anderson\'s whimsical style shines in The Grand Budapest Hotel. With its quirky characters and colorful cinematography, it\'s a visual and narrative delight. This film is a charming and delightful experience."\n',
#  '6."Inception is mind-bending brilliance! Christopher Nolan\'s intricate plot, stunning visual effects, and Hans Zimmer\'s haunting score create a cinematic journey that keeps you on the edge of your seat. A true masterpiece of sci-fi cinema."\n',
#  '7. "The Social Network is a captivating exploration of the creation of Facebook and the personal and legal conflicts that ensued. David Fincher\'s direction and Aaron Sorkin\'s sharp screenplay make this film a modern classic."\n',
#  '8. "Will Smith\'s portrayal of Chris Gardner in The Pursuit of Happyness is both touching and inspirational. This film reminds us that with determination and unwavering spirit, anyone can overcome adversity to achieve their dreams."\n',
#  '9. "Eternal Sunshine of the Spotless Mind is a beautifully unconventional love story. Jim Carrey and Kate Winslet shine in their roles, and the narrative, told in a non-linear fashion, is a poignant exploration of love, memories, and human connection."\n',
#  '10. "The Princess Bride is a timeless fairy tale with a perfect blend of humor, romance, and adventure. Its witty dialogue and memorable characters make it a film that appeals to both kids and adults. Inconceivably delightful!"\n',
#  '11. "Fifty Shades of Grey" has managed to captivate both enthusiasts and critics alike. The film\'s ability to spark passionate discussions and elicit a wide range of opinions is a testament to its impact. While some may find it controversial, there\'s no denying that it has left a significant mark on the world of cinema.\n',
#  '12. "This film has been a conversation starter, and it\'s clear that it won\'t be everyone\'s cup of tea. But for those willing to approach it with an open mind, there\'s a visually lush experience with moments of genuine chemistry between the leads. It\'s a film that has managed to offer something different and intriguing in the world of romance and drama."\n']

# %%
negative_reviews
# Out:
# ['1. "The Last Airbender is a disaster of a film adaptation. It butchers the beloved animated series with wooden acting, convoluted storytelling, and cringe-worthy special effects. A letdown for fans and newcomers alike."\n',
#  '2. "Another Transformers movie, and it\'s just more of the same: mindless explosions, incoherent plotlines, and an overreliance on CGI. This franchise desperately needs an overhaul."\n',
#  '3. "The Emoji Movie is a blatant cash grab with a shallow, uninspired plot. It fails to deliver clever humor or meaningful messages, making it a forgettable and disappointing animated film."\n',
#  '4. "Fifty Shades of Grey is a cringe-inducing attempt at romance. Poorly written dialogue and unconvincing chemistry between the leads make it an awkward and unfulfilling cinematic experience."\n',
#  '5. "Jack and Jill is an unbearable comedy that relies on stale humor and a painfully unfunny portrayal of Adam Sandler in a dual role. It\'s a prime example of lazy filmmaking."\n',
#  '6. "Superman IV is a colossal disappointment. It\'s marred by a low budget, laughable special effects, and a poorly conceived story. Even Christopher Reeve\'s charm can\'t save this mess."\n',
#  '7. "The Cat in the Hat is a chaotic and misguided adaptation of Dr. Seuss\'s classic. It sacrifices the charm and simplicity of the source material for crude humor and a lackluster narrative."\n',
#  '8. "The Room is widely regarded as one of the worst films ever made. Its disjointed plot, stilted acting, and bizarre dialogue have turned it into a cult classic, but not for the right reasons."\n',
#  '9. "Battlefield Earth is a sci-fi disaster. It\'s a convoluted mess with hammy acting and laughable special effects. A film that should have remained buried in the annals of cinematic history."\n',
#  '10. "Gigli is a train wreck of a romantic comedy. The pairing of Ben Affleck and Jennifer Lopez is devoid of chemistry, and the dialogue is cringeworthy. It\'s an embarrassing misstep in both their careers."\n',
#  '11. "Fifty Shades of Grey" is a film that has divided enthusiasts and critics. While it has its share of devoted fans, it also faces substantial criticism. For some, the film\'s content and execution leave much to be desired, making it a polarizing cinematic experience. Viewer reactions may vary widely, so it\'s a movie that evokes strong opinions on both ends of the spectrum.\n',
#  '12. "This film\'s portrayal of relationships and themes may leave many viewers uncomfortable. It tests the limits of what some may find acceptable in mainstream cinema. So, while the idea of keeping an open mind is essential in film-watching, this particular movie might push that openness to its boundaries for some."\n']

# %%
test_reviews
# Out:
# ["It's clear that the movie has both its enthusiasts and critics. While it may not be to everyone's taste, it's worth watching with an open mind to form your own opinion. \n"]

# %% [markdown]
# * Removing numbers and dots associated with numbers

# %%
postive_reviews_without_numbers = [re.sub(r'\d+\.', '', string) for string in positive_reviews]
negtive_reviews_without_numbers = [re.sub(r'\d+\.', '', string) for string in negative_reviews]

# %% [markdown]
# * Creating the dataframe

# %%
df_positive = pd.DataFrame({'reviews': postive_reviews_without_numbers, 'sentiments': 'positive'})
df_negative = pd.DataFrame({'reviews': negtive_reviews_without_numbers, 'sentiments': 'negative'})

# %%
df = pd.concat([df_positive, df_negative], ignore_index=True)

# %%
df.head()
# Out:
#                                              reviews sentiments
# 0   "Forrest Gump is an absolute masterpiece! Tom...   positive
# 1   "The Shawshank Redemption is a timeless class...   positive
# 2   "The epic conclusion to The Lord of the Rings...   positive
# 3   "La La Land is a love letter to the magic of ...   positive
# 4   "Wes Anderson's whimsical style shines in The...   positive

# %%
nltk.download('stopwords')
tokenizer=word_tokenize
#Setting English stopwords
stopword_list=nltk.corpus.stopwords.words('english')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## **2. Pre-processing Reviews**

# %%
# Removing special characters from reviews

def remove_special_characters(text, remove_digits=True):
    pattern=r'[^a-zA-z0-9\s]'
    text=re.sub(pattern,'',text)
    return text

df['reviews']=df['reviews'].apply(remove_special_characters)

# %%
# Lowercasing reviews

def lowercase_text(text):
  return text.lower()

df['reviews']=df['reviews'].apply(lowercase_text)

# %%
# Tokenizing reviews

def tokenize_reviews(text):
  tokens = tokens = tokenizer(text)
  tokens = [token.strip() for token in tokens]
  return tokens

df['tokens']=df['reviews'].apply(tokenize_reviews)

# %%
#removing the stopwords from tokens

stop=set(stopwords.words('english'))
print(stop)

def remove_stopwords(tokens):
  filtered_tokens = [token for token in tokens if token not in stopword_list]
  return filtered_tokens

df['tokens']=df['tokens'].apply(remove_stopwords)
# Out:
# {'who', 'me', 'of', 'shan', "that'll", 'that', 'all', 'doing', 'a', 'after', 'aren', 'it', 'but', 'because', 'most', 'does', 'am', 'same', 'mightn', 'them', 'be', 'itself', 'so', 'below', 'him', 'no', 'you', 'their', 'yours', 'is', 'at', 'here', 'was', 'don', 'during', 'your', 'do', 'doesn', 'has', 'these', 'before', "weren't", 'where', 's', 't', 'which', 'once', 'hadn', 'couldn', 'than', 'under', 'm', 'up', "you'll", 'whom', 'again', 'as', "doesn't", 'wasn', 'what', "you're", "hadn't", "hasn't", 'very', 'being', 'she', "don't", 'and', 'didn', 'are', "couldn't", 'why', 'down', 'above', 'only', 'just', "wouldn't", 'shouldn', 'or', 'between', 'some', 'themselves', 'from', 'each', 'myself', "isn't", 'few', 'can', 'other', 'did', "mustn't", 'had', "you've", 'our', 'when', 'such', "wasn't", "mightn't", 'i', 'his', 'y', 'hers', 'nor', 'haven', 'won', 'on', "didn't", 'mustn', 'my', 'should', 'he', 'with', 'herself', 'yourselves', "you'd", 'this', 'have', 'how', "aren't", 'o', 'off', 'through', 'been', "it's", 'now', 'having', 'to', 'until', "haven't", 'further', 'its', 'for', 'in', 'we', 'ourselves', 'they', 'by', 'there', 'any', 'both', 'will', 'more', 'll', 'were', 'theirs', 'while', 'wouldn', 've', 'into', 'weren', "won't", 're', 'about', 'himself', 'ain', 'too', 'an', 'over', 'ma', 'needn', 'ours', 'the', 'then', 'her', 'against', 'd', 'hasn', "shan't", 'those', "shouldn't", "needn't", "she's", 'not', 'isn', 'yourself', "should've", 'out', 'if', 'own'}

# %%
df['tokens'].head(10)
# Out:
# 0    [forrest, gump, absolute, masterpiece, tom, ha...
# 1    [shawshank, redemption, timeless, classic, pow...
# 2    [epic, conclusion, lord, rings, trilogy, retur...
# 3    [la, la, land, love, letter, magic, hollywood,...
# 4    [wes, andersons, whimsical, style, shines, gra...
# 5    [inception, mindbending, brilliance, christoph...
# 6    [social, network, captivating, exploration, cr...
# 7    [smiths, portrayal, chris, gardner, pursuit, h...
# 8    [eternal, sunshine, spotless, mind, beautifull...
# 9    [princess, bride, timeless, fairy, tale, perfe...
# Name: tokens, dtype: object

# %%
# Lemmatizing tokens to get them in to their base form

nltk.download('wordnet')

def lemmatize_tokens(tokens):
    lemmatizer = WordNetLemmatizer()
    lemmatized_words = [lemmatizer.lemmatize(token, pos='n') for token in tokens]
    lemmatized_words = [lemmatizer.lemmatize(token, pos='v') for token in lemmatized_words]  # Also lemmatize verbs
    lemmatized_words = [lemmatizer.lemmatize(token, pos='a') for token in lemmatized_words]  # Also lemmatize adjectives
    lemmatized_words = [lemmatizer.lemmatize(token, pos='r') for token in lemmatized_words]  # Also lemmatize adverbs
    return lemmatized_words
#Apply function on review column
df['lem_tokens']=df['tokens'].apply(lemmatize_tokens)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
df['lem_tokens'].iloc[2]
# Out:
# ['epic',
#  'conclusion',
#  'lord',
#  'ring',
#  'trilogy',
#  'return',
#  'king',
#  'cinematic',
#  'triumph',
#  'breathtaking',
#  'visuals',
#  'epic',
#  'battle',
#  'emotionally',
#  'resonant',
#  'story',
#  'make',
#  'monumental',
#  'achievement',
#  'filmmaking']

# %%
df['tokens'].iloc[2]
# Out:
# ['epic',
#  'conclusion',
#  'lord',
#  'rings',
#  'trilogy',
#  'return',
#  'king',
#  'cinematic',
#  'triumph',
#  'breathtaking',
#  'visuals',
#  'epic',
#  'battles',
#  'emotionally',
#  'resonant',
#  'story',
#  'make',
#  'monumental',
#  'achievement',
#  'filmmaking']

# %%
# encoding sentiment class labels usin labelEncoder

le = LabelEncoder()

df['sentiments'] = le.fit_transform(df['sentiments'])
print(le.classes_)
# Out:
# ['negative' 'positive']

# %%
print("Positive label is encoded as : ",le.transform(['positive'])[0])
print("Negative label is encoded as : ",le.transform(['negative'])[0])
# Out:
# Positive label is encoded as :  1
# Negative label is encoded as :  0

# %%
# Concatinatin the lemmatized tokens to get the lemmatized review text

def lemmatized_text(tokens):
  lem_text = " ".join(tokens)
  return lem_text

df['lem_text'] = df['lem_tokens'].apply(lemmatized_text)

# %%
df.head()
# Out:
#                                              reviews  sentiments  \
# 0   forrest gump is an absolute masterpiece tom h...           1
# 1   the shawshank redemption is a timeless classi...           1
# 2   the epic conclusion to the lord of the rings ...           1
# 3   la la land is a love letter to the magic of h...           1
# 4   wes andersons whimsical style shines in the g...           1
#
#                                               tokens  \
# 0  [forrest, gump, absolute, masterpiece, tom, ha...
# 1  [shawshank, redemption, timeless, classic, pow...
# 2  [epic, conclusion, lord, rings, trilogy, retur...
# 3  [la, la, land, love, letter, magic, hollywood,...
# 4  [wes, andersons, whimsical, style, shines, gra...
#
#                                           lem_tokens  \
# 0  [forrest, gump, absolute, masterpiece, tom, ha...
# 1  [shawshank, redemption, timeless, classic, pow...
# 2  [epic, conclusion, lord, ring, trilogy, return...
# 3  [la, la, land, love, letter, magic, hollywood,...
# 4  [wes, anderson, whimsical, style, shine, grand...
#
#                                             lem_text
# 0  forrest gump absolute masterpiece tom hank del...
# 1  shawshank redemption timeless classic powerful...
# 2  epic conclusion lord ring trilogy return king ...
# 3  la la land love letter magic hollywood dream c...
# 4  wes anderson whimsical style shine grand budap...

# %% [markdown]
# ## **3. Calculating N-gram Probabilities**

# %%
# generate bigrams

def generate_bigrams(tokens):
    return list(ngrams(tokens, 2))

df['bigrams'] = df['tokens'].apply(generate_bigrams)

# %%
df['bigrams']
# Out:
# 0     [(forrest, gump), (gump, absolute), (absolute,...
# 1     [(shawshank, redemption), (redemption, timeles...
# 2     [(epic, conclusion), (conclusion, lord), (lord...
# 3     [(la, la), (la, land), (land, love), (love, le...
# 4     [(wes, andersons), (andersons, whimsical), (wh...
# 5     [(inception, mindbending), (mindbending, brill...
# 6     [(social, network), (network, captivating), (c...
# 7     [(smiths, portrayal), (portrayal, chris), (chr...
# 8     [(eternal, sunshine), (sunshine, spotless), (s...
# 9     [(princess, bride), (bride, timeless), (timele...
# 10    [(fifty, shades), (shades, grey), (grey, manag...
# 11    [(film, conversation), (conversation, starter)...
# 12    [(last, airbender), (airbender, disaster), (di...
# 13    [(another, transformers), (transformers, movie...
# 14    [(emoji, movie), (movie, blatant), (blatant, c...
# 15    [(fifty, shades), (shades, grey), (grey, cring...
# 16    [(jack, jill), (jill, unbearable), (unbearable...
# 17    [(superman, iv), (iv, colossal), (colossal, di...
# 18    [(cat, hat), (hat, chaotic), (chaotic, misguid...
# 19    [(room, widely), (widely, regarded), (regarded...
# 20    [(battlefield, earth), (earth, scifi), (scifi,...
# 21    [(gigli, train), (train, wreck), (wreck, roman...
# 22    [(fifty, shades), (shades, grey), (grey, film)...
# 23    [(films, portrayal), (portrayal, relationships...
# Name: bigrams, dtype: object

# %%
# getting all unique bigrams

df_exploded = df['bigrams'].explode()
unique_bigrams = df_exploded.unique().tolist()

# %%
print("Unique bigrams : ",len(unique_bigrams))
# Out:
# Unique bigrams :  473

# %%
# calculating bigram probabilities

def calculate_bigram_probabilities(bigram):
  phrase = " ".join(map(str, bigram))
  positive_bigram_count = sum(phrase in sentence.lower() for sentence in postive_reviews_without_numbers)
  postive_prior_word_count = sum(bigram[0] in sentence.lower() for sentence in postive_reviews_without_numbers)
  if(postive_prior_word_count == 0):
      postive_bigram_probability = 0
  else:
      postive_bigram_probability = positive_bigram_count/postive_prior_word_count

  positive_bigram_probabilities[bigram] = postive_bigram_probability

  negative_bigram_count = sum(phrase in sentence.lower() for sentence in negtive_reviews_without_numbers)
  negative_prior_word_count = sum(bigram[0] in sentence.lower() for sentence in negtive_reviews_without_numbers)
  if(negative_prior_word_count == 0):
      negative_bigram_probability = 0
  else:
      negative_bigram_probability = negative_bigram_count/negative_prior_word_count

  negative_bigram_probabilities[bigram] = negative_bigram_probability

# %%
# adding positive and negative bigram probability values for seperate dictionries

positive_bigram_probabilities = {}
negative_bigram_probabilities = {}

for bigram in unique_bigrams:
  calculate_bigram_probabilities(bigram)

# %%
# positive bigram probabilities
table_data_positive = [(key, value) for key, value in positive_bigram_probabilities.items()]
print(tabulate(table_data_positive, headers=["Key", "Value"], tablefmt="fancy_grid"))
# Out:
# ╒═══════════════════════════════════╤══════════╕
# │ Key                               │    Value │
# ╞═══════════════════════════════════╪══════════╡
# │ ('forrest', 'gump')               │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('gump', 'absolute')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('absolute', 'masterpiece')       │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('masterpiece', 'tom')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('tom', 'hanks')                  │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('hanks', 'delivers')             │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('delivers', 'unforgettable')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('unforgettable', 'performance')  │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('performance', 'storytelling')   │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('storytelling', 'heartwarming')  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('heartwarming', 'movie')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('movie', 'journey')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('journey', 'life')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('life', 'make')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('make', 'laugh')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('laugh', 'cry')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cry', 'appreciate')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('appreciate', 'simple')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('simple', 'beauties')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('beauties', 'existence')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('shawshank', 'redemption')       │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('redemption', 'timeless')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('timeless', 'classic')           │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('classic', 'powerful')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('powerful', 'themes')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('themes', 'hope')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('hope', 'friendship')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('friendship', 'redemption')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('redemption', 'make')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('make', 'mustwatch')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('mustwatch', 'morgan')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('morgan', 'freeman')             │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('freeman', 'tim')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('tim', 'robbins')                │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('robbins', 'give')               │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('give', 'exceptional')           │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('exceptional', 'performances')   │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('performances', 'brilliantly')   │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('brilliantly', 'crafted')        │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('crafted', 'film')               │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('epic', 'conclusion')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('conclusion', 'lord')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('lord', 'rings')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('rings', 'trilogy')              │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('trilogy', 'return')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('return', 'king')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('king', 'cinematic')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cinematic', 'triumph')          │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('triumph', 'breathtaking')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('breathtaking', 'visuals')       │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('visuals', 'epic')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('epic', 'battles')               │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('battles', 'emotionally')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('emotionally', 'resonant')       │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('resonant', 'story')             │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('story', 'make')                 │ 0.333333 │
# ├───────────────────────────────────┼──────────┤
# │ ('make', 'monumental')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('monumental', 'achievement')     │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('achievement', 'filmmaking')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('la', 'la')                      │ 0.2      │
# ├───────────────────────────────────┼──────────┤
# │ ('la', 'land')                    │ 0.2      │
# ├───────────────────────────────────┼──────────┤
# │ ('land', 'love')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('love', 'letter')                │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('letter', 'magic')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('magic', 'hollywood')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('hollywood', 'dreams')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('dreams', 'chemistry')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('chemistry', 'ryan')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('ryan', 'gosling')               │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('gosling', 'emma')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('emma', 'stone')                 │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('stone', 'enchanting')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('enchanting', 'music')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('music', 'dance')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('dance', 'sequences')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('sequences', 'pure')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('pure', 'delight')               │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('delight', 'modern')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('modern', 'musical')             │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('musical', 'masterpiece')        │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('wes', 'andersons')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('andersons', 'whimsical')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('whimsical', 'style')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('style', 'shines')               │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('shines', 'grand')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('grand', 'budapest')             │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('budapest', 'hotel')             │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('hotel', 'quirky')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('quirky', 'characters')          │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('characters', 'colorful')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('colorful', 'cinematography')    │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('cinematography', 'visual')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('visual', 'narrative')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('narrative', 'delight')          │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('delight', 'film')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('film', 'charming')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('charming', 'delightful')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('delightful', 'experience')      │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('inception', 'mindbending')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('mindbending', 'brilliance')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('brilliance', 'christopher')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('christopher', 'nolans')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('nolans', 'intricate')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('intricate', 'plot')             │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('plot', 'stunning')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('stunning', 'visual')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('visual', 'effects')             │ 0.25     │
# ├───────────────────────────────────┼──────────┤
# │ ('effects', 'hans')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('hans', 'zimmers')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('zimmers', 'haunting')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('haunting', 'score')             │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('score', 'create')               │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('create', 'cinematic')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cinematic', 'journey')          │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('journey', 'keeps')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('keeps', 'edge')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('edge', 'seat')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('seat', 'true')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('true', 'masterpiece')           │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('masterpiece', 'scifi')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('scifi', 'cinema')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('social', 'network')             │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('network', 'captivating')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('captivating', 'exploration')    │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('exploration', 'creation')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('creation', 'facebook')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('facebook', 'personal')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('personal', 'legal')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('legal', 'conflicts')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('conflicts', 'ensued')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('ensued', 'david')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('david', 'finchers')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('finchers', 'direction')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('direction', 'aaron')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('aaron', 'sorkins')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('sorkins', 'sharp')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('sharp', 'screenplay')           │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('screenplay', 'make')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('make', 'film')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('film', 'modern')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('modern', 'classic')             │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('smiths', 'portrayal')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('portrayal', 'chris')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('chris', 'gardner')              │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('gardner', 'pursuit')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('pursuit', 'happyness')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('happyness', 'touching')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('touching', 'inspirational')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('inspirational', 'film')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('film', 'reminds')               │ 0.125    │
# ├───────────────────────────────────┼──────────┤
# │ ('reminds', 'us')                 │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('us', 'determination')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('determination', 'unwavering')   │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('unwavering', 'spirit')          │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('spirit', 'anyone')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('anyone', 'overcome')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('overcome', 'adversity')         │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('adversity', 'achieve')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('achieve', 'dreams')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('eternal', 'sunshine')           │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('sunshine', 'spotless')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('spotless', 'mind')              │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('mind', 'beautifully')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('beautifully', 'unconventional') │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('unconventional', 'love')        │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('love', 'story')                 │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('story', 'jim')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('jim', 'carrey')                 │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('carrey', 'kate')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('kate', 'winslet')               │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('winslet', 'shine')              │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('shine', 'roles')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('roles', 'narrative')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('narrative', 'told')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('told', 'nonlinear')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('nonlinear', 'fashion')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('fashion', 'poignant')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('poignant', 'exploration')       │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('exploration', 'love')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('love', 'memories')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('memories', 'human')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('human', 'connection')           │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('princess', 'bride')             │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('bride', 'timeless')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('timeless', 'fairy')             │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('fairy', 'tale')                 │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('tale', 'perfect')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('perfect', 'blend')              │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('blend', 'humor')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('humor', 'romance')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('romance', 'adventure')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('adventure', 'witty')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('witty', 'dialogue')             │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('dialogue', 'memorable')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('memorable', 'characters')       │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('characters', 'make')            │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('film', 'appeals')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('appeals', 'kids')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('kids', 'adults')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('adults', 'inconceivably')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('inconceivably', 'delightful')   │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('fifty', 'shades')               │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('shades', 'grey')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('grey', 'managed')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('managed', 'captivate')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('captivate', 'enthusiasts')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('enthusiasts', 'critics')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('critics', 'alike')              │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('alike', 'films')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('films', 'ability')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('ability', 'spark')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('spark', 'passionate')           │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('passionate', 'discussions')     │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('discussions', 'elicit')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('elicit', 'wide')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('wide', 'range')                 │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('range', 'opinions')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('opinions', 'testament')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('testament', 'impact')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('impact', 'may')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('may', 'find')                   │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('find', 'controversial')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('controversial', 'theres')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('theres', 'denying')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('denying', 'left')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('left', 'significant')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('significant', 'mark')           │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('mark', 'world')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('world', 'cinema')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('film', 'conversation')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('conversation', 'starter')       │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('starter', 'clear')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('clear', 'wont')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('wont', 'everyones')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('everyones', 'cup')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cup', 'tea')                    │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('tea', 'willing')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('willing', 'approach')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('approach', 'open')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('open', 'mind')                  │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('mind', 'theres')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('theres', 'visually')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('visually', 'lush')              │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('lush', 'experience')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('experience', 'moments')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('moments', 'genuine')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('genuine', 'chemistry')          │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('chemistry', 'leads')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('leads', 'film')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('film', 'managed')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('managed', 'offer')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('offer', 'something')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('something', 'different')        │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('different', 'intriguing')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('intriguing', 'world')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('world', 'romance')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('romance', 'drama')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('last', 'airbender')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('airbender', 'disaster')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('disaster', 'film')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('film', 'adaptation')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('adaptation', 'butchers')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('butchers', 'beloved')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('beloved', 'animated')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('animated', 'series')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('series', 'wooden')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('wooden', 'acting')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('acting', 'convoluted')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('convoluted', 'storytelling')    │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('storytelling', 'cringeworthy')  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cringeworthy', 'special')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('special', 'effects')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('effects', 'letdown')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('letdown', 'fans')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('fans', 'newcomers')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('newcomers', 'alike')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('another', 'transformers')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('transformers', 'movie')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('movie', 'mindless')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('mindless', 'explosions')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('explosions', 'incoherent')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('incoherent', 'plotlines')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('plotlines', 'overreliance')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('overreliance', 'cgi')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cgi', 'franchise')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('franchise', 'desperately')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('desperately', 'needs')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('needs', 'overhaul')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('emoji', 'movie')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('movie', 'blatant')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('blatant', 'cash')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cash', 'grab')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('grab', 'shallow')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('shallow', 'uninspired')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('uninspired', 'plot')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('plot', 'fails')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('fails', 'deliver')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('deliver', 'clever')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('clever', 'humor')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('humor', 'meaningful')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('meaningful', 'messages')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('messages', 'making')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('making', 'forgettable')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('forgettable', 'disappointing')  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('disappointing', 'animated')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('animated', 'film')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('grey', 'cringeinducing')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cringeinducing', 'attempt')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('attempt', 'romance')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('romance', 'poorly')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('poorly', 'written')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('written', 'dialogue')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('dialogue', 'unconvincing')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('unconvincing', 'chemistry')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('leads', 'make')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('make', 'awkward')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('awkward', 'unfulfilling')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('unfulfilling', 'cinematic')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cinematic', 'experience')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('jack', 'jill')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('jill', 'unbearable')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('unbearable', 'comedy')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('comedy', 'relies')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('relies', 'stale')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('stale', 'humor')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('humor', 'painfully')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('painfully', 'unfunny')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('unfunny', 'portrayal')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('portrayal', 'adam')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('adam', 'sandler')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('sandler', 'dual')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('dual', 'role')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('role', 'prime')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('prime', 'example')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('example', 'lazy')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('lazy', 'filmmaking')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('superman', 'iv')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('iv', 'colossal')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('colossal', 'disappointment')    │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('disappointment', 'marred')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('marred', 'low')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('low', 'budget')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('budget', 'laughable')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('laughable', 'special')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('effects', 'poorly')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('poorly', 'conceived')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('conceived', 'story')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('story', 'even')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('even', 'christopher')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('christopher', 'reeves')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('reeves', 'charm')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('charm', 'cant')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cant', 'save')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('save', 'mess')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cat', 'hat')                    │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('hat', 'chaotic')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('chaotic', 'misguided')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('misguided', 'adaptation')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('adaptation', 'dr')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('dr', 'seusss')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('seusss', 'classic')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('classic', 'sacrifices')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('sacrifices', 'charm')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('charm', 'simplicity')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('simplicity', 'source')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('source', 'material')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('material', 'crude')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('crude', 'humor')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('humor', 'lackluster')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('lackluster', 'narrative')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('room', 'widely')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('widely', 'regarded')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('regarded', 'one')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('one', 'worst')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('worst', 'films')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('films', 'ever')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('ever', 'made')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('made', 'disjointed')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('disjointed', 'plot')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('plot', 'stilted')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('stilted', 'acting')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('acting', 'bizarre')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('bizarre', 'dialogue')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('dialogue', 'turned')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('turned', 'cult')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cult', 'classic')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('classic', 'right')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('right', 'reasons')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('battlefield', 'earth')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('earth', 'scifi')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('scifi', 'disaster')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('disaster', 'convoluted')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('convoluted', 'mess')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('mess', 'hammy')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('hammy', 'acting')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('acting', 'laughable')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('effects', 'film')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('film', 'remained')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('remained', 'buried')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('buried', 'annals')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('annals', 'cinematic')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cinematic', 'history')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('gigli', 'train')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('train', 'wreck')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('wreck', 'romantic')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('romantic', 'comedy')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('comedy', 'pairing')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('pairing', 'ben')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('ben', 'affleck')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('affleck', 'jennifer')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('jennifer', 'lopez')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('lopez', 'devoid')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('devoid', 'chemistry')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('chemistry', 'dialogue')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('dialogue', 'cringeworthy')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cringeworthy', 'embarrassing')  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('embarrassing', 'misstep')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('misstep', 'careers')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('grey', 'film')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('film', 'divided')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('divided', 'enthusiasts')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('critics', 'share')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('share', 'devoted')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('devoted', 'fans')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('fans', 'also')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('also', 'faces')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('faces', 'substantial')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('substantial', 'criticism')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('criticism', 'films')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('films', 'content')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('content', 'execution')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('execution', 'leave')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('leave', 'much')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('much', 'desired')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('desired', 'making')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('making', 'polarizing')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('polarizing', 'cinematic')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('experience', 'viewer')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('viewer', 'reactions')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('reactions', 'may')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('may', 'vary')                   │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('vary', 'widely')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('widely', 'movie')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('movie', 'evokes')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('evokes', 'strong')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('strong', 'opinions')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('opinions', 'ends')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('ends', 'spectrum')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('films', 'portrayal')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('portrayal', 'relationships')    │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('relationships', 'themes')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('themes', 'may')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('may', 'leave')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('leave', 'many')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('many', 'viewers')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('viewers', 'uncomfortable')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('uncomfortable', 'tests')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('tests', 'limits')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('limits', 'may')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('find', 'acceptable')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('acceptable', 'mainstream')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('mainstream', 'cinema')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cinema', 'idea')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('idea', 'keeping')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('keeping', 'open')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('mind', 'essential')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('essential', 'filmwatching')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('filmwatching', 'particular')    │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('particular', 'movie')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('movie', 'might')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('might', 'push')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('push', 'openness')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('openness', 'boundaries')        │ 0        │
# ╘═══════════════════════════════════╧══════════╛

# %%
# negative bigram probabilities

table_data_negative = [(key, value) for key, value in negative_bigram_probabilities.items()]
print(tabulate(table_data_negative, headers=["Key", "Value"], tablefmt="fancy_grid"))
# Out:
# ╒═══════════════════════════════════╤══════════╕
# │ Key                               │    Value │
# ╞═══════════════════════════════════╪══════════╡
# │ ('forrest', 'gump')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('gump', 'absolute')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('absolute', 'masterpiece')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('masterpiece', 'tom')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('tom', 'hanks')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('hanks', 'delivers')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('delivers', 'unforgettable')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('unforgettable', 'performance')  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('performance', 'storytelling')   │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('storytelling', 'heartwarming')  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('heartwarming', 'movie')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('movie', 'journey')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('journey', 'life')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('life', 'make')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('make', 'laugh')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('laugh', 'cry')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cry', 'appreciate')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('appreciate', 'simple')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('simple', 'beauties')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('beauties', 'existence')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('shawshank', 'redemption')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('redemption', 'timeless')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('timeless', 'classic')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('classic', 'powerful')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('powerful', 'themes')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('themes', 'hope')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('hope', 'friendship')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('friendship', 'redemption')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('redemption', 'make')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('make', 'mustwatch')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('mustwatch', 'morgan')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('morgan', 'freeman')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('freeman', 'tim')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('tim', 'robbins')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('robbins', 'give')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('give', 'exceptional')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('exceptional', 'performances')   │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('performances', 'brilliantly')   │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('brilliantly', 'crafted')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('crafted', 'film')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('epic', 'conclusion')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('conclusion', 'lord')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('lord', 'rings')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('rings', 'trilogy')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('trilogy', 'return')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('return', 'king')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('king', 'cinematic')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cinematic', 'triumph')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('triumph', 'breathtaking')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('breathtaking', 'visuals')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('visuals', 'epic')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('epic', 'battles')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('battles', 'emotionally')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('emotionally', 'resonant')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('resonant', 'story')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('story', 'make')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('make', 'monumental')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('monumental', 'achievement')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('achievement', 'filmmaking')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('la', 'la')                      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('la', 'land')                    │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('land', 'love')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('love', 'letter')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('letter', 'magic')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('magic', 'hollywood')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('hollywood', 'dreams')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('dreams', 'chemistry')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('chemistry', 'ryan')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('ryan', 'gosling')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('gosling', 'emma')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('emma', 'stone')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('stone', 'enchanting')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('enchanting', 'music')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('music', 'dance')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('dance', 'sequences')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('sequences', 'pure')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('pure', 'delight')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('delight', 'modern')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('modern', 'musical')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('musical', 'masterpiece')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('wes', 'andersons')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('andersons', 'whimsical')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('whimsical', 'style')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('style', 'shines')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('shines', 'grand')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('grand', 'budapest')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('budapest', 'hotel')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('hotel', 'quirky')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('quirky', 'characters')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('characters', 'colorful')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('colorful', 'cinematography')    │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cinematography', 'visual')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('visual', 'narrative')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('narrative', 'delight')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('delight', 'film')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('film', 'charming')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('charming', 'delightful')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('delightful', 'experience')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('inception', 'mindbending')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('mindbending', 'brilliance')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('brilliance', 'christopher')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('christopher', 'nolans')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('nolans', 'intricate')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('intricate', 'plot')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('plot', 'stunning')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('stunning', 'visual')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('visual', 'effects')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('effects', 'hans')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('hans', 'zimmers')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('zimmers', 'haunting')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('haunting', 'score')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('score', 'create')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('create', 'cinematic')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cinematic', 'journey')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('journey', 'keeps')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('keeps', 'edge')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('edge', 'seat')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('seat', 'true')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('true', 'masterpiece')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('masterpiece', 'scifi')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('scifi', 'cinema')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('social', 'network')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('network', 'captivating')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('captivating', 'exploration')    │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('exploration', 'creation')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('creation', 'facebook')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('facebook', 'personal')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('personal', 'legal')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('legal', 'conflicts')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('conflicts', 'ensued')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('ensued', 'david')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('david', 'finchers')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('finchers', 'direction')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('direction', 'aaron')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('aaron', 'sorkins')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('sorkins', 'sharp')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('sharp', 'screenplay')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('screenplay', 'make')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('make', 'film')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('film', 'modern')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('modern', 'classic')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('smiths', 'portrayal')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('portrayal', 'chris')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('chris', 'gardner')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('gardner', 'pursuit')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('pursuit', 'happyness')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('happyness', 'touching')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('touching', 'inspirational')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('inspirational', 'film')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('film', 'reminds')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('reminds', 'us')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('us', 'determination')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('determination', 'unwavering')   │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('unwavering', 'spirit')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('spirit', 'anyone')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('anyone', 'overcome')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('overcome', 'adversity')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('adversity', 'achieve')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('achieve', 'dreams')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('eternal', 'sunshine')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('sunshine', 'spotless')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('spotless', 'mind')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('mind', 'beautifully')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('beautifully', 'unconventional') │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('unconventional', 'love')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('love', 'story')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('story', 'jim')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('jim', 'carrey')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('carrey', 'kate')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('kate', 'winslet')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('winslet', 'shine')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('shine', 'roles')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('roles', 'narrative')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('narrative', 'told')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('told', 'nonlinear')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('nonlinear', 'fashion')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('fashion', 'poignant')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('poignant', 'exploration')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('exploration', 'love')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('love', 'memories')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('memories', 'human')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('human', 'connection')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('princess', 'bride')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('bride', 'timeless')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('timeless', 'fairy')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('fairy', 'tale')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('tale', 'perfect')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('perfect', 'blend')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('blend', 'humor')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('humor', 'romance')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('romance', 'adventure')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('adventure', 'witty')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('witty', 'dialogue')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('dialogue', 'memorable')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('memorable', 'characters')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('characters', 'make')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('film', 'appeals')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('appeals', 'kids')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('kids', 'adults')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('adults', 'inconceivably')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('inconceivably', 'delightful')   │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('fifty', 'shades')               │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('shades', 'grey')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('grey', 'managed')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('managed', 'captivate')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('captivate', 'enthusiasts')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('enthusiasts', 'critics')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('critics', 'alike')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('alike', 'films')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('films', 'ability')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('ability', 'spark')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('spark', 'passionate')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('passionate', 'discussions')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('discussions', 'elicit')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('elicit', 'wide')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('wide', 'range')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('range', 'opinions')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('opinions', 'testament')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('testament', 'impact')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('impact', 'may')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('may', 'find')                   │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('find', 'controversial')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('controversial', 'theres')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('theres', 'denying')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('denying', 'left')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('left', 'significant')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('significant', 'mark')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('mark', 'world')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('world', 'cinema')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('film', 'conversation')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('conversation', 'starter')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('starter', 'clear')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('clear', 'wont')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('wont', 'everyones')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('everyones', 'cup')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cup', 'tea')                    │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('tea', 'willing')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('willing', 'approach')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('approach', 'open')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('open', 'mind')                  │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('mind', 'theres')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('theres', 'visually')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('visually', 'lush')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('lush', 'experience')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('experience', 'moments')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('moments', 'genuine')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('genuine', 'chemistry')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('chemistry', 'leads')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('leads', 'film')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('film', 'managed')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('managed', 'offer')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('offer', 'something')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('something', 'different')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('different', 'intriguing')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('intriguing', 'world')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('world', 'romance')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('romance', 'drama')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('last', 'airbender')             │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('airbender', 'disaster')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('disaster', 'film')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('film', 'adaptation')            │ 0.142857 │
# ├───────────────────────────────────┼──────────┤
# │ ('adaptation', 'butchers')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('butchers', 'beloved')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('beloved', 'animated')           │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('animated', 'series')            │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('series', 'wooden')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('wooden', 'acting')              │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('acting', 'convoluted')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('convoluted', 'storytelling')    │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('storytelling', 'cringeworthy')  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cringeworthy', 'special')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('special', 'effects')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('effects', 'letdown')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('letdown', 'fans')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('fans', 'newcomers')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('newcomers', 'alike')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('another', 'transformers')       │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('transformers', 'movie')         │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('movie', 'mindless')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('mindless', 'explosions')        │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('explosions', 'incoherent')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('incoherent', 'plotlines')       │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('plotlines', 'overreliance')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('overreliance', 'cgi')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cgi', 'franchise')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('franchise', 'desperately')      │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('desperately', 'needs')          │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('needs', 'overhaul')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('emoji', 'movie')                │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('movie', 'blatant')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('blatant', 'cash')               │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('cash', 'grab')                  │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('grab', 'shallow')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('shallow', 'uninspired')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('uninspired', 'plot')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('plot', 'fails')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('fails', 'deliver')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('deliver', 'clever')             │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('clever', 'humor')               │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('humor', 'meaningful')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('meaningful', 'messages')        │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('messages', 'making')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('making', 'forgettable')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('forgettable', 'disappointing')  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('disappointing', 'animated')     │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('animated', 'film')              │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('grey', 'cringeinducing')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cringeinducing', 'attempt')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('attempt', 'romance')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('romance', 'poorly')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('poorly', 'written')             │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('written', 'dialogue')           │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('dialogue', 'unconvincing')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('unconvincing', 'chemistry')     │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('leads', 'make')                 │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('make', 'awkward')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('awkward', 'unfulfilling')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('unfulfilling', 'cinematic')     │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('cinematic', 'experience')       │ 0.666667 │
# ├───────────────────────────────────┼──────────┤
# │ ('jack', 'jill')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('jill', 'unbearable')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('unbearable', 'comedy')          │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('comedy', 'relies')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('relies', 'stale')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('stale', 'humor')                │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('humor', 'painfully')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('painfully', 'unfunny')          │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('unfunny', 'portrayal')          │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('portrayal', 'adam')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('adam', 'sandler')               │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('sandler', 'dual')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('dual', 'role')                  │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('role', 'prime')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('prime', 'example')              │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('example', 'lazy')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('lazy', 'filmmaking')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('superman', 'iv')                │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('iv', 'colossal')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('colossal', 'disappointment')    │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('disappointment', 'marred')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('marred', 'low')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('low', 'budget')                 │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('budget', 'laughable')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('laughable', 'special')          │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('effects', 'poorly')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('poorly', 'conceived')           │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('conceived', 'story')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('story', 'even')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('even', 'christopher')           │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('christopher', 'reeves')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('reeves', 'charm')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('charm', 'cant')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cant', 'save')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('save', 'mess')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cat', 'hat')                    │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('hat', 'chaotic')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('chaotic', 'misguided')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('misguided', 'adaptation')       │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('adaptation', 'dr')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('dr', 'seusss')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('seusss', 'classic')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('classic', 'sacrifices')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('sacrifices', 'charm')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('charm', 'simplicity')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('simplicity', 'source')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('source', 'material')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('material', 'crude')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('crude', 'humor')                │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('humor', 'lackluster')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('lackluster', 'narrative')       │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('room', 'widely')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('widely', 'regarded')            │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('regarded', 'one')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('one', 'worst')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('worst', 'films')                │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('films', 'ever')                 │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('ever', 'made')                  │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('made', 'disjointed')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('disjointed', 'plot')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('plot', 'stilted')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('stilted', 'acting')             │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('acting', 'bizarre')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('bizarre', 'dialogue')           │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('dialogue', 'turned')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('turned', 'cult')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cult', 'classic')               │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('classic', 'right')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('right', 'reasons')              │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('battlefield', 'earth')          │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('earth', 'scifi')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('scifi', 'disaster')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('disaster', 'convoluted')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('convoluted', 'mess')            │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('mess', 'hammy')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('hammy', 'acting')               │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('acting', 'laughable')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('effects', 'film')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('film', 'remained')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('remained', 'buried')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('buried', 'annals')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('annals', 'cinematic')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cinematic', 'history')          │ 0.333333 │
# ├───────────────────────────────────┼──────────┤
# │ ('gigli', 'train')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('train', 'wreck')                │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('wreck', 'romantic')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('romantic', 'comedy')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('comedy', 'pairing')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('pairing', 'ben')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('ben', 'affleck')                │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('affleck', 'jennifer')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('jennifer', 'lopez')             │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('lopez', 'devoid')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('devoid', 'chemistry')           │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('chemistry', 'dialogue')         │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('dialogue', 'cringeworthy')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('cringeworthy', 'embarrassing')  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('embarrassing', 'misstep')       │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('misstep', 'careers')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('grey', 'film')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('film', 'divided')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('divided', 'enthusiasts')        │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('critics', 'share')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('share', 'devoted')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('devoted', 'fans')               │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('fans', 'also')                  │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('also', 'faces')                 │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('faces', 'substantial')          │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('substantial', 'criticism')      │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('criticism', 'films')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('films', 'content')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('content', 'execution')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('execution', 'leave')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('leave', 'much')                 │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('much', 'desired')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('desired', 'making')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('making', 'polarizing')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('polarizing', 'cinematic')       │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('experience', 'viewer')          │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('viewer', 'reactions')           │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('reactions', 'may')              │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('may', 'vary')                   │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('vary', 'widely')                │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('widely', 'movie')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('movie', 'evokes')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('evokes', 'strong')              │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('strong', 'opinions')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('opinions', 'ends')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('ends', 'spectrum')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('films', 'portrayal')            │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('portrayal', 'relationships')    │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('relationships', 'themes')       │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('themes', 'may')                 │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('may', 'leave')                  │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('leave', 'many')                 │ 0.5      │
# ├───────────────────────────────────┼──────────┤
# │ ('many', 'viewers')               │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('viewers', 'uncomfortable')      │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('uncomfortable', 'tests')        │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('tests', 'limits')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('limits', 'may')                 │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('find', 'acceptable')            │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('acceptable', 'mainstream')      │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('mainstream', 'cinema')          │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('cinema', 'idea')                │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('idea', 'keeping')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('keeping', 'open')               │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('mind', 'essential')             │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('essential', 'filmwatching')     │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('filmwatching', 'particular')    │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('particular', 'movie')           │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('movie', 'might')                │ 0.25     │
# ├───────────────────────────────────┼──────────┤
# │ ('might', 'push')                 │ 1        │
# ├───────────────────────────────────┼──────────┤
# │ ('push', 'openness')              │ 0        │
# ├───────────────────────────────────┼──────────┤
# │ ('openness', 'boundaries')        │ 0        │
# ╘═══════════════════════════════════╧══════════╛

# %%
# pre-processing test review

test_review = "It's clear that the movie has both its enthusiasts and critics. While it may not be to everyone's taste, it's worth watching with an open mind to form your own opinion. "

test_review = remove_special_characters(test_review)
test_review = lowercase_text(test_review)
tokenized_test_review = tokenize_reviews(test_review)
tokenized_test_review = remove_stopwords(tokenized_test_review)
tokenized_test_review = lemmatize_tokens(tokenized_test_review)

tokenized_test_review
# Out:
# ['clear',
#  'movie',
#  'enthusiast',
#  'critic',
#  'may',
#  'everyones',
#  'taste',
#  'worth',
#  'watch',
#  'open',
#  'mind',
#  'form',
#  'opinion']

# %%
test_bigrams = generate_bigrams(tokenized_test_review)
test_bigrams
# Out:
# [('clear', 'movie'),
#  ('movie', 'enthusiast'),
#  ('enthusiast', 'critic'),
#  ('critic', 'may'),
#  ('may', 'everyones'),
#  ('everyones', 'taste'),
#  ('taste', 'worth'),
#  ('worth', 'watch'),
#  ('watch', 'open'),
#  ('open', 'mind'),
#  ('mind', 'form'),
#  ('form', 'opinion')]

# %% [markdown]
# * Since there are unseen bigrams, I use "Add-One (Laplace) Smoothing here to get the probability of the test review with regards to each class.

# %%
def get_smoothed_probabilities_positive(bigram):
  phrase = " ".join(map(str, bigram))
  bigram_count = sum(phrase in sentence.lower() for sentence in postive_reviews_without_numbers) + 1
  prior_word_count = sum(bigram[0] in sentence.lower() for sentence in postive_reviews_without_numbers) + 465
  probability = bigram_count/prior_word_count
  return probability;

# %%
exploded_df = df['tokens'].explode().reset_index(drop=True)
unique_words = exploded_df.unique()
V = len(unique_words)
V
# Out:
# 394

# %%
def get_smoothed_probabilities_negative(bigram):
  phrase = " ".join(map(str, bigram))
  bigram_count = sum(phrase in sentence.lower() for sentence in negtive_reviews_without_numbers) + 1
  prior_word_count = sum(bigram[0] in sentence.lower() for sentence in negtive_reviews_without_numbers) + V
  probability = bigram_count/prior_word_count
  return probability;

# %%
positive_probability = 1
for bigram in test_bigrams:
  positive_probability = positive_probability * get_smoothed_probabilities_positive(bigram)

print("Probability for the test review to be positive : ",positive_probability)
# Out:
# Probability for the test review to be positive :  1.9031805771933046e-32

# %%
negative_probability = 1
for bigram in test_bigrams:
  negative_probability = negative_probability * get_smoothed_probabilities_negative(bigram)

print("Probability for the test review to be negative : ", negative_probability)
# Out:
# Probability for the test review to be negative :  1.3759011137590818e-31

# %% [markdown]
# > test(positive) probability < test(negative) probability <br>
# **Therefore as the conclusion we can say the sentiment of the test review is Negative**

# %% [markdown]
# ## **4. Sentiment Analysis Using in-built Naive Bayes Model and Functions**

# %%
# Splitting data in to train set and test set

X_train, X_test, y_train, y_test = train_test_split(df['lem_text'], df['sentiments'], test_size=0.3, random_state=42)

# %%
X_train.head()
# Out:
# 21    gigli train wreck romantic comedy pair ben aff...
# 5     inception mindbending brilliance christopher n...
# 2     epic conclusion lord ring trilogy return king ...
# 12    last airbender disaster film adaptation butch ...
# 15    fifty shade grey cringeinducing attempt romanc...
# Name: lem_text, dtype: object

# %%
# transforming train and test set to Bag of Words using CounterVectorizer

cv=CountVectorizer(min_df=0,max_df=1,binary=False,ngram_range=(1,3))
cv_train_reviews=cv.fit_transform(X_train)
cv_test_reviews=cv.transform(X_test)

print('BOW_train :',cv_train_reviews.shape)
print('BOW_test :',cv_test_reviews.shape)
# Out:
# BOW_train : (16, 841)
# BOW_test : (8, 841)

# %%
X_test.head()
# Out:
# 8     eternal sunshine spotless mind beautifully unc...
# 16    jack jill unbearable comedy rely stale humor p...
# 0     forrest gump absolute masterpiece tom hank del...
# 18    cat hat chaotic misguide adaptation dr seusss ...
# 11    film conversation starter clear wont everyones...
# Name: lem_text, dtype: object

# %%
# Fitting train data to Naive Bayes Model

mnb=MultinomialNB()
nb_model=mnb.fit(cv_train_reviews,y_train)

# %%
# Predicting the sentiments for test set using countervectorized features
nb_model_predict = mnb.predict(cv_test_reviews)
print(nb_model_predict)
# Out:
# [1 0 0 0 0 1 0 0]

# %%
# Accuracy of the Naive Bayes Model

nb_model_score=accuracy_score(y_test,nb_model_predict)
print("nb_model_score :",nb_model_score)
# Out:
# nb_model_score : 0.625

# %%
# Classification report for Naive Bayes Model

nb_model_report=classification_report(y_test,nb_model_predict,target_names=['Positive','Negative'])
print(nb_model_report)
# Out:
#               precision    recall  f1-score   support
#
#     Positive       0.50      1.00      0.67         3
#     Negative       1.00      0.40      0.57         5
#
#     accuracy                           0.62         8
#    macro avg       0.75      0.70      0.62         8
# weighted avg       0.81      0.62      0.61         8

# %% [markdown]
# ### **4.1. Prediction**

# %%
test_review = "It's clear that the movie has both its enthusiasts and critics. While it may not be to everyone's taste, it's worth watching with an open mind to form your own opinion. "

test_review = remove_special_characters(test_review)
test_review = lowercase_text(test_review)
tokenized_test_review = tokenize_reviews(test_review)
tokenized_test_review = remove_stopwords(tokenized_test_review)
tokenized_test_review = lemmatize_tokens(tokenized_test_review)

lemmatized_test_review = lemmatized_text(tokenized_test_review)
lemmatized_test_review
# Out:
# 'clear movie enthusiast critic may everyones taste worth watch open mind form opinion'

# %%
text = [lemmatized_test_review]

# %%
# test_review_vectorized = mnb.fit([' '.join(test_review)])
x = cv.transform(text)

# %%
sentiment_prediction = nb_model.predict(x)

# %%
if sentiment_prediction[0]:
  print("Predicted Sentiment: Positive")
else:
  print("Predicted Sentiment: Negative")
# Out:
# Predicted Sentiment: Negative

# %% [markdown]
# ---
